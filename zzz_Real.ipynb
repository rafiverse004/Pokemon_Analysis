# %% [markdown]
# 🧾 COMPANY BRIEF (Pokémon Analytics Task)
#
# 📌 Context
#
# You are a Junior Data Analyst at a gaming analytics company.
# We study Pokémon data to understand game balance, power distribution, and design patterns.
#
# The product team wants insights for balancing future Pokémon designs.

# %% [markdown]
# 🎯 BUSINESS GOAL
#
# Understand what makes a Pokémon “strong” and how strength varies across:
#
# types
#
# generations
#
# legendary status

# %% [markdown]
# 📊 RAW DATA YOU RECEIVE
#
# You have a dataset with:
#
# base stats (HP, Attack, Defense, Speed, etc.)
#
# Type 1 / Type 2
#
# Generation
#
# Legendary flag

# %% [markdown]
# 🧠 01_load_inspect.py — TASK (Data Understanding Stage)
#
# 🎯 Goal
#
# Understand what data you are working with. No cleaning yet.
#
# 📌 TASKS YOU MUST DO
# 1. Load dataset
# Read CSV into pandas DataFrame
#
#
# 2. Basic structure check
#
# Find:
#
#     number of rows
#     number of columns
#     column names
#
#
# 3. First look at data
#
# Show:
#
#     first 5 rows
#     last 5 rows
#     random sample (to avoid bias)
#
#
# 4. Data types inspection
#
# Check:
#
#     numeric columns
#     categorical columns
#     any weird/mis-typed columns
#
#
# 5. Summary statistics
#
# Generate:
#
#     basic stats for numeric columns
#     include object stats too
#
#
# 6. Data quality quick scan
#
# Find:
#
#     missing values per column
#     duplicate rows count
#
#
# 7. Column-level understanding
#
# For key columns:
#
#     Type 1
#     Type 2
#     Generation
#     Legendary
#
# Show:
#
#     value counts
#
#
# 📊 OUTPUT YOU SHOULD SEE
#
# At the end of 01_load_inspect.py, you should know:
#
#     dataset size
#     structure
#     column meaning
#     data types
#     missing data
#     duplicates
#     distribution of key categories
